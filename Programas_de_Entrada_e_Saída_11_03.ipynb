# %% [markdown]
# <a href="https://colab.research.google.com/github/oruben01/Aulas-de-PA/blob/main/Programas_de_Entrada_e_Sa%C3%ADda_11_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Cálculo área do retângulo

# Entrada

comprimento = float (input("Digite o valor do comprimento: "))
altura = float (input("Digite o valor da altura: "))

# Processamento

area = comprimento * altura

#Saída

print(f"Area do retângulo é igual: {area}")
# Out:
# Digite o valor do comprimento: 12
# Digite o valor da altura: 12
# Area do retângulo é igual: 144.0

# %%
# Escreve um programa que calcula o dobro de um número

#Entrada

numero = int (input("Digite um número: "))

# Processamento

dobro = numero * 2

# Saída

print (f"O dobro de {numero} é igual a: {dobro}")
# Out:
# Digite um número: 9
# O dobro de 9 é igual a: 18

# %%
# Escrever um cadastro de usuário

# Entrada: nome e idade
# Processamneto: armazenar os dados do usuário
# Saída: Mostrar uma mensagem de boas vindas e o nome e a idade do usuário

# Entrada

nome = str (input("Digite o seu nome: "))
idade = int (input("Digite sua idade: "))

# Processamento

# Saída

print (f"Olá {nome}, seja bem vindo! ")
print (f"Você tem {idade} anos." )
# Out:
# Digite o seu nome: Ruben
# Digite sua idade: 16
# Olá Ruben, seja bem vindo!
# Você tem 16 anos.

# %% [markdown]
# **Soma**: +
#
# **Subtração**: -
#
# **Multiplicação**: *
#
# **Divisão**: /

# %%
# Escrever um algoritimo que calcula o triplo de um número

# Entrada

numero = int (input("Digite um número: "))

# Processamento

triplo = numero * 3

# Saída

print (f"O trplo de {numero} é igual a: {triplo}")
# Out:
# Digite um número: 6
# O trplo de 6 é igual a: 18

# %% [markdown]
# **Escrever um programa que receba o nome do usuário e a idade e mostre uma mensagem com o ano que ele nasceu**

# %%
# Entrada

nome = str (input("Digite seu nome: "))
idade = int (input("Digite sua idade: "))

# Processmento

nascimento = 2026 - idade


# Saída

print (f"olá {nome}, você nasceu em:")
# Out:
# Digite seu nome: Ruben
# Digite sua idade: 15
# olá Ruben, você nasceu em:

# %% [markdown]
# Escrever um programa que faz a conversão de temperatura
#
# Entrada: Temperatura em Celsius
#
# Processamento: converter para Fahrenheit
#
# Saída; resultado.
#
# Fórmula: F = (Cx9/5) + 32
