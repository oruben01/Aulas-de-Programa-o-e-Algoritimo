# %% [markdown]
# <a href="https://colab.research.google.com/github/oruben01/Aulas-de-Programa-o-e-Algoritimo/blob/main/Aula_de_PA_C%C3%A1lculo_da_%C3%81rea.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aula de programação e algoritimos
# -Calculo da área
#
# #Entrada
#
# - ler lado 1
# - ler lado 2
#
# #Processamento
#
# area = lado1 * lado2
#
# #Saída
# imprimir area
#
# #Cálculo da área
#
# #Entrada
#
# lado1 = 5
# lado2 = 4

# %%
# Entrada

lado1 = 5
lado2 = 4

nome = "Ruben Ribeiro"

# Saída

print (nome)
# Out:
# Ruben Ribeiro

# %%
# Processamento

area = lado1 * lado2

# %%
# Saída

print (f"Total da área: {area}")
# Out:
# Total da área: 20

# %%
# Tipos Numéricos
idade = 16 # int
altura = 1.60 # float
numero_complexo = 2 + 3j #complex

#Tipo Texto

nome = "Alice" # srt

#Tipo Boleano

esta_chovendo = False # boot
